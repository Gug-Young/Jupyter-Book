# %% [markdown]
# ---
# title: Generate and Display Rich Outputs
# short_title: Generate Rich Outputs
# subtitle: Discover the types of cell outputs and metadata that MyST understands
# description: MyST allows you to include interactive visualizations directly in your projects using Jupyter Notebooks.
# thumbnail: ./PASTE_IMAGE/2025-11-14-00-35-57.png
# project:
#   jupyter: true
# ---

# %% [markdown]
# MyST allows you to directly include Jupyter Notebooks in your books, documents and websites. This page of the documentation is actually a Jupyter Notebook that is rendered directly using MyST.
#
# See below for several examples.
#
# ## Supported cell outputs
#
# ### Interactive visualizations
#
# You can include interactive visualizations that were created by executing code in Jupyter.
# For example, let us import `altair` and create a demo of an interactive plot!

# %%
# !pip install altair
# !pip install vega_datasets
# Out:
# Requirement already satisfied: altair in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from altair) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from altair) (4.23.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from altair) (1.42.1)
# Requirement already satisfied: packaging in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from altair) (24.2)
# Requirement already satisfied: typing-extensions>=4.12.0 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from altair) (4.13.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=3.0->altair) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=3.0->altair) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=3.0->altair) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=3.0->altair) (0.24.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->altair) (3.0.2)
# Requirement already satisfied: vega_datasets in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.9.0)
# Requirement already satisfied: pandas in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from vega_datasets) (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->vega_datasets) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->vega_datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->vega_datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->vega_datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\kim9y\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas->vega_datasets) (1.17.0)

# %%
import altair as alt
from vega_datasets import data

source = data.cars()
brush = alt.selection_interval(encodings=['x'])
points = alt.Chart(source).mark_point().encode(
    x='Horsepower:Q',
    y='Miles_per_Gallon:Q',
    size='Acceleration',
    color=alt.condition(brush, 'Origin:N', alt.value('lightgray'))
).add_params(brush)

bars = alt.Chart(source).mark_bar().encode(
    y='Origin:N',
    color='Origin:N',
    x='count(Origin):Q'
).transform_filter(brush)

# %% [markdown]
# We can now plot the `altair` example, which is fully interactive, try dragging in the plot to select cars by their horsepower.

# %%
#| label: img:altair-horsepower
points & bars
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Static images
#
# Non-interactive images are embedded as PNGs:

# %%
#| label: img:mpl
#| caption: Horsepower and miles per gallon, from `vega_datasets`
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.scatter("Horsepower", "Miles_per_Gallon",
           c="Acceleration", data=data.cars())
_ = ax.set(xlabel="Horsepower", ylabel="Miles per gallon",
       title="Horsepower and miles per gallon")

# %% [markdown]
# ### Tables and DataFrames
#
# This works for non-image outputs as well.
# For example, below we'll **output a Table via a Pandas DataFrame**.
# We'll show the contents of a dataset loaded above, along with syntax to [label the cell in order to be embedded later](reuse-jupyter-outputs.md).

# %%
#| label: tbl:data-cars
# Take a subset of cars so it displays nicely
data.cars().iloc[:5, :5]
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower
# 0       130.0
# 1       165.0
# 2       150.0
# 3       150.0
# 4       140.0

# %% [markdown]
# ### Text outputs

# %% [markdown]
# And here we demonstrate a text-based output.

# %%
#| label:zen
import this

# %% [markdown]
# (notebooks:cell-visibility)=
#
# ## Control cell visibility
#
# You can control the visibility of cell inputs and outputs by using **cell metadata tags**.
# These are special snippets of text that you can attach to a cell in a Jupyter interface like JupyterLab.
#
# The following tags are supported.
#
# Use the **`remove-input`** tag to remove the cell input:

# %%
print("A text output with no input!")
# Out:
# A text output with no input!

# %% [markdown]
# Use the **`remove-output`** tag to remove the cell output but keep the input:

# %%
print("The input of a cell with no output!")
# Out:
# The input of a cell with no output!

# %% [markdown]
# Use the **`remove-cell`** tag to entirely remove the entire cell (for example, if it contains sensitive information that you don't want distributed with your MyST document).

# %%
# THIS IS ONLY FOR DEVELOPERS
# It shouldn't show up in the documentation at all.
# If it does, it means that there's likely a regression!
#label: removed-cell
print("Removed cell")
# Out:
# Removed cell

# %% [markdown]
# ## Include notebooks in your MyST site
#
# If you are working with Jupyter `*.ipynb` files, just move your notebooks into the project folder or list them in your table of contents to get them to show up in your website or as a document. `myst` will then include your notebook in parsing, and show the full results as soon as you save your notebook, including any interactive figures.
#
# To customize the title and other frontmatter, ensure the first Jupyter Notebook cell is a markdown cell, and only includes a `YAML` frontmatter block (i.e. surrounded in `---`).

# %% [markdown]
# ## MyST in Jupyter User Interfaces
#
# If you'd like to write and read MyST Markdown in Jupyter interfaces, check out the [JupyterLab MyST Extension](./quickstart-jupyter-lab-myst.md).
# It allows for rich rendering of MyST markdown, frontmatter, and cross-references directly in JupyterLab.
