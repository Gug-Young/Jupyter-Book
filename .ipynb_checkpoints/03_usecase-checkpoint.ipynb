# %% [markdown]
# # First example

# %% [markdown]
# $ e = m c^2 $ <my-math-label>
#
# See #link(<my-math-label>)[(1)] for an equation!

# %% [markdown]
# ::::{tab-set}
# :::{tab-item} Kuramoto
# :::{note}
# $r e^{i\psi} = \frac{1}{N}\sum_j e^{i\theta_j}$
# :::
# :::
# :::{tab-item} Vicsek
# 밀도/잡음에 따른 밴드 형성 사례.
# :::
# ::::\

# %% [markdown]
# This math is a role, {math}`e=mc^2`, while this math is wrapped in dollar signs, $Ax=b$.

# %% [markdown]
# $$
# \label{maxwell}
# \begin{aligned}
# \nabla \times \vec{e}+\frac{\partial \vec{b}}{\partial t}&=0 \\
# \nabla \times \vec{h}-\vec{j}&=\vec{s}\_{e}
# \end{aligned}
# $$
#
# $$ \label{one-liner} Ax=b $$
#
# See [](#maxwell) for enlightenment and [](#one-liner) to do things on one line!

# %%
import numpy as np
import matplotlib.pyplot as plt
